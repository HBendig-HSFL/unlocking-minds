# %% [markdown]
# # GAN Modell zur Generierung von synthetischen Daten

# %%
# Import necessary libraries
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from keras import Sequential
from keras.layers import Input, Dense, LeakyReLU, Dropout, BatchNormalization
from keras.optimizers import Adam
import keras

# %%
print(tf.__version__)
print(keras.__version__)

print(tf.config.list_physical_devices('GPU'))
# Out:
# 2.15.1
# 3.3.3
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Data Preparation

# %%
# Daten laden
data = pd.read_csv('./../data/preprocessed_df_v2.csv')  # Pfad zu Ihren Daten
columns_to_drop = ['gender', 'age', 'education', 'visual_acuity_logmar']  
data = data.drop(columns_to_drop, axis=1)
data.head(10)
# Out:
#    participant_id  test_id  test_duration  mental  physical  temporal  \
# 0               1        1      33.643950      10         5        15
# 1               1        2      28.484322      50        30        25
# 2               1        3      71.423823     100        10        75
# 3               1        4      38.163442      60        15        45
# 4               2        1      41.748047      20        10        20
# 5               2        2      29.480232      50        10        60
# 6               2        3      42.027676      50        10        20
# 7               2        4      49.023876      85        10        90
# 8               3        1      42.350301       5         5         5
# 9               3        2      45.063506      15        10        10
#
#    performance  effort  frustration  mean  ...  blinkrate  fixationrate  \
# 0           25      25           10  15.0  ...   0.059446      0.295946
# 1           50      15           25  32.5  ...   0.000000      0.175533
# 2           80      90           20  62.5  ...   0.196013      0.196018
# 3           50      20           25  35.8  ...   0.052406      0.288263
# 4           10      20           15  15.8  ...   0.000000      0.143727
# 5           30      30           25  34.2  ...   0.000000      0.305280
# 6           25      50           20  29.2  ...   0.142763      0.214771
# 7           90      80           85  73.3  ...   0.203982      0.265198
# 8            0       5            5   4.2  ...   0.141675      0.259758
# 9            0      15            5   9.2  ...   0.088764      0.288480
#
#    blinkrate_rel  blinkrate_rel_pct  fixationrate_rel  fixationrate_rel_pct  \
# 0       0.000000           0.000000          0.000000              0.000000
# 1      -0.059446        -100.000000         -0.120413            -40.687440
# 2       0.136567         229.732630         -0.099928            -33.765546
# 3      -0.007040         -11.842464         -0.007684             -2.596309
# 4       0.000000                NaN          0.000000              0.000000
# 5       0.000000                NaN          0.161553            112.403281
# 6       0.142763                NaN          0.071045             49.430587
# 7       0.203982                NaN          0.121471             84.515659
# 8       0.000000           0.000000          0.000000              0.000000
# 9      -0.052912         -37.347232          0.028722             11.057291
#
#    mean_pupil_diameter_rel  mean_pupil_diameter_rel_pct  \
# 0                 0.000000                     0.000000
# 1                -0.919996                    -2.097788
# 2                 0.848925                     1.935731
# 3                 1.906622                     4.347507
# 4                 0.000000                     0.000000
# 5                 1.755946                     5.575779
# 6                 2.737221                     8.691690
# 7                 3.477475                    11.042269
# 8                 0.000000                     0.000000
# 9                 0.304355                     0.977945
#
#    median_pupil_diameter_rel  median_pupil_diameter_rel_pct
# 0                   0.000000                       0.000000
# 1                  -0.872377                      -1.987465
# 2                   0.897654                       2.045050
# 3                   1.951494                       4.445927
# 4                   0.000000                       0.000000
# 5                   1.726040                       5.498150
# 6                   2.750065                       8.760093
# 7                   3.637966                      11.588426
# 8                   0.000000                       0.000000
# 9                   0.622330                       2.028103
#
# [10 rows x 22 columns]

# %%
# Extrahiere Participant und Test IDs
participant_ids = data['participant_id']
test_ids = data['test_id']

# Entferne die ID-Spalten aus den Daten, die skaliert werden sollen
data_for_scaling = data.drop(['participant_id', 'test_id'], axis=1)

# Auffüllen von NaN-Werten mit dem Mittelwert der jeweiligen Spalte
data_for_scaling = data_for_scaling.fillna(data_for_scaling.mean())

# Überprüfen auf NaN-Werte in den Daten
assert not np.any(np.isnan(data_for_scaling)), "Daten enthalten NaN-Werte"

# Daten skalieren
scaler = MinMaxScaler(feature_range=(-1, 1))
data_scaled = scaler.fit_transform(data_for_scaling)

# Die skalierten Daten wieder mit den IDs zusammenführen
data_scaled = pd.DataFrame(data_scaled, columns=data_for_scaling.columns)
data_scaled['participant_id'] = participant_ids
data_scaled['test_id'] = test_ids

# die hinzugefügten IDs an den Anfang der Daten verschieben
cols = data_scaled.columns.tolist()
cols = cols[-2:] + cols[:-2]
data_scaled = data_scaled[cols]


print(data_scaled.head())

# GAN-Parameter
latent_dim = 100
data_dim = data_scaled.shape[1] - 2  # Nicht die ID-Spalten mitzählen
# Out:
#    participant_id  test_id  test_duration    mental  physical  temporal  \
# 0               1        1      -0.993814 -0.894737 -1.000000 -0.789474
# 1               1        2      -0.995240 -0.052632 -0.473684 -0.578947
# 2               1        3      -0.983375  1.000000 -0.894737  0.473684
# 3               1        4      -0.992565  0.157895 -0.789474 -0.157895
# 4               2        1      -0.991575 -0.684211 -0.894737 -0.684211
#
#    performance    effort  frustration    mean  ...  blinkrate  fixationrate  \
# 0    -0.473684 -0.578947    -0.894737 -0.7300  ...  -0.874455      0.072029
# 1     0.052632 -0.789474    -0.578947 -0.2925  ...  -1.000000     -0.364152
# 2     0.684211  0.789474    -0.684211  0.4575  ...  -0.586037     -0.289947
# 3     0.052632 -0.684211    -0.578947 -0.2100  ...  -0.889323      0.044196
# 4    -0.789474 -0.684211    -0.789474 -0.7100  ...  -1.000000     -0.479368
#
#    blinkrate_rel  blinkrate_rel_pct  fixationrate_rel  fixationrate_rel_pct  \
# 0      -0.695111          -0.945943         -0.020242             -0.354614
# 1      -0.805887          -1.000000         -0.468261             -0.617205
# 2      -0.440623          -0.821756         -0.392043             -0.572532
# 3      -0.708230          -0.952345         -0.048831             -0.371370
# 4      -0.695111          -0.795287         -0.020242             -0.354614
#
#    mean_pupil_diameter_rel  mean_pupil_diameter_rel_pct  \
# 0                -0.716078                    -0.678150
# 1                -0.891427                    -0.815600
# 2                -0.554275                    -0.551318
# 3                -0.352681                    -0.393294
# 4                -0.716078                    -0.678150
#
#    median_pupil_diameter_rel  median_pupil_diameter_rel_pct
# 0                  -0.609270                      -0.604331
# 1                  -0.747820                      -0.722506
# 2                  -0.466705                      -0.482733
# 3                  -0.299336                      -0.339977
# 4                  -0.609270                      -0.604331
#
# [5 rows x 22 columns]

# %% [markdown]
# ## GAN Definition

# %%
# Generator-Modell
def build_generator(latent_dim, data_dim, num_participants, num_tests):
    # Eingabe für die IDs
    participant_input = keras.layers.Input(shape=(1,))
    test_input = keras.layers.Input(shape=(1,))
    latent_input = keras.layers.Input(shape=(latent_dim,))
    
    # Embedding für kategorielle Eingaben
    participant_embedding = keras.layers.Embedding(num_participants, 5)(participant_input)
    test_embedding = keras.layers.Embedding(num_tests, 5)(test_input)
    
    # flatten
    participant_flat = keras.layers.Flatten()(participant_embedding)
    test_flat = keras.layers.Flatten()(test_embedding)
    
    # Kombinieren der Eingaben
    combined_input = keras.layers.concatenate([latent_input, participant_flat, test_flat])
    
    # Weiter mit dem vorherigen Modell
    x = keras.layers.Dense(128)(combined_input)
    x = keras.layers.LeakyReLU(alpha=0.2)(x)
    x = keras.layers.Dense(256)(x)
    x = keras.layers.LeakyReLU(alpha=0.2)(x)
    x = keras.layers.Dense(512)(x)
    x = keras.layers.LeakyReLU(alpha=0.2)(x)
    output = keras.layers.Dense(data_dim, activation='tanh')(x)
    
    model = keras.Model(inputs=[latent_input, participant_input, test_input], outputs=output)
    return model

# Diskriminator-Modell
def build_discriminator(data_dim, num_participants, num_tests):
    # Eingabe für die Daten
    data_input = keras.layers.Input(shape=(data_dim,))
    participant_input = keras.layers.Input(shape=(1,))
    test_input = keras.layers.Input(shape=(1,))

    # Embedding für kategoriale Eingaben
    participant_embedding = keras.layers.Embedding(num_participants, 5)(participant_input)
    test_embedding = keras.layers.Embedding(num_tests, 5)(test_input)
    
    # Flachlegen der Embeddings
    participant_flat = keras.layers.Flatten()(participant_embedding)
    test_flat = keras.layers.Flatten()(test_embedding)
    
    # Kombinieren der Eingaben
    combined_input = keras.layers.concatenate([data_input, participant_flat, test_flat])
    
    # Weiter mit dem vorherigen Modell
    x = keras.layers.Dense(512)(combined_input)
    x = keras.layers.LeakyReLU(alpha=0.2)(x)
    x = keras.layers.Dense(256)(x)
    x = keras.layers.LeakyReLU(alpha=0.2)(x)
    x = keras.layers.Dense(128)(x)
    x = keras.layers.LeakyReLU(alpha=0.2)(x)
    output = keras.layers.Dense(1, activation='sigmoid')(x)
    
    model = keras.Model(inputs=[data_input, participant_input, test_input], outputs=output)
    return model

# GAN-Modell
def build_gan(generator, discriminator):
    # Stelle sicher, dass der Diskriminator beim Trainieren des GANs nicht aktualisiert wird
    discriminator.trainable = False
    
    # Eingaben für das GAN-Modell
    latent_input = keras.layers.Input(shape=(generator.input_shape[0][1],))
    participant_input = keras.layers.Input(shape=(1,))
    test_input = keras.layers.Input(shape=(1,))
    
    # Generator und Diskriminator verbinden
    generated_data = generator([latent_input, participant_input, test_input])
    gan_output = discriminator([generated_data, participant_input, test_input])
    
    # GAN-Modell erstellen
    model = keras.Model(inputs=[latent_input, participant_input, test_input], outputs=gan_output)
    return model

# %%
# Hyperparameter
learning_rate_discriminator = 0.00005
learning_rate_generator = 0.0001

num_participants = data_scaled['participant_id'].nunique()
num_tests = 4

# Modelle mit konditionierten Inputs erstellen
generator = build_generator(latent_dim, data_dim, num_participants, num_tests)
discriminator = build_discriminator(data_dim, num_participants, num_tests)

# Kompilieren des Diskriminators
discriminator.compile(optimizer=Adam(learning_rate_discriminator, 0.5), loss='binary_crossentropy', metrics=['accuracy'])

# Diskriminator trainierbar auf False setzen für GAN
discriminator.trainable = False

# GAN-Modell erstellen
gan = build_gan(generator, discriminator)
gan.compile(optimizer=Adam(learning_rate_generator, 0.5), loss='binary_crossentropy')

# Vorbereiten der Eingaben für das Training
participant_ids = data_scaled['participant_id'].values
test_ids = data_scaled['test_id'].values

# Die tatsächlichen skalierten Trainingsdaten ohne die ID-Spalten
real = data_scaled.drop(['participant_id', 'test_id'], axis=1).values
real_labels = np.ones((real.shape[0], 1))
fake_labels = np.zeros((real.shape[0], 1))
# Out:
# /home/x/miniconda3/envs/tf/lib/python3.11/site-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(

# %% [markdown]
# ## Training

# %%
# GAN-Training
epochs = 100 
batch_size = 32

d_losses = []
g_losses = []

for epoch in range(epochs):
    idx = np.random.randint(0, real.shape[0], batch_size)
    real_samples = real[idx]
    real_participant_ids = participant_ids[idx]
    real_test_ids = test_ids[idx]
    
    # Umwandlung in Tensoren mit festgelegter Form
    real_participant_ids_tensor = tf.constant(real_participant_ids, dtype=tf.int32, shape=(batch_size, 1))
    real_test_ids_tensor = tf.constant(real_test_ids, dtype=tf.int32, shape=(batch_size, 1))
    
    # Zufälliges Rauschen und Fake-Daten generieren
    noise = np.random.normal(0, 1, (batch_size, latent_dim))
    fake_samples = generator.predict([noise, real_participant_ids, real_test_ids])
    
    # Diskriminator trainieren
    d_loss_real = discriminator.train_on_batch([real_samples, real_participant_ids, real_test_ids], real_labels[:batch_size])
    d_loss_fake = discriminator.train_on_batch([fake_samples, real_participant_ids, real_test_ids], fake_labels[:batch_size])
    d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
    
    # GAN trainieren (das Ziel ist, den Diskriminator zu täuschen)
    g_loss = gan.train_on_batch([noise, real_participant_ids, real_test_ids], real_labels[:batch_size])
    
    # Verluste speichern
    d_losses.append(d_loss[0])
    g_losses.append(g_loss)
    
    # Fortschritt ausgeben
    if (epoch + 1) % 1 == 0:  # Ersetzt 1000 durch 1 für das Debugging
        print(f"{epoch + 1} [D loss: {d_loss[0]}, acc.: {100*d_loss[1]}%] [G loss: {g_loss}]")


print("Training abgeschlossen!")
print(f"{epochs} [D loss: {d_loss[0]}, acc.: {100*d_loss[1]}%] [G loss: {g_loss}]")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# /home/x/miniconda3/envs/tf/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py:71: UserWarning: The model does not have any trainable weights.
#   warnings.warn("The model does not have any trainable weights.")
# 1 [D loss: 0.7014625072479248, acc.: 50.0%] [G loss: [array(0.68860435, dtype=float32), array(0.68860435, dtype=float32), array(0.65625, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2 [D loss: 0.6990742087364197, acc.: 55.46875%] [G loss: [array(0.6943083, dtype=float32), array(0.6943083, dtype=float32), array(0.609375, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 3 [D loss: 0.6958706378936768, acc.: 58.229172229766846%] [G loss: [array(0.6933621, dtype=float32), array(0.6933621, dtype=float32), array(0.6145834, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 4 [D loss: 0.6988697648048401, acc.: 53.90625%] [G loss: [array(0.697737, dtype=float32), array(0.697737, dtype=float32), array(0.546875, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 5 [D loss: 0.7006006240844727, acc.: 50.53819417953491%] [G loss: [array(0.70048785, dtype=float32), array(0.70048785, dtype=float32), array(0.49687502, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 6 [D loss: 0.7037420868873596, acc.: 46.34233117103577%] [G loss: [array(0.70345414, dtype=float32), array(0.70345414, dtype=float32), array(0.4609375, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 7 [D loss: 0.7062681913375854, acc.: 42.96875298023224%] [G loss: [array(0.70625746, dtype=float32), array(0.70625746, dtype=float32), array(0.42187503, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 8 [D loss: 0.7083835601806641, acc.: 39.53125178813934%] [G loss: [array(0.70841026, dtype=float32), array(0.70841026, dtype=float32), array(0.390625, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 9 [D loss: 0.7095787525177002, acc.: 37.69403696060181%] [G loss: [array(0.70975834, dtype=float32), array(0.70975834, dtype=float32), array(0.3715278, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 10 [D loss: 0.7115670442581177, acc.: 34.794408082962036%] [G loss: [array(0.71193016, dtype=float32), array(0.71193016, dtype=float32), array(0.34062502, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 11 [D loss: 0.7136988639831543, acc.: 32.575756311416626%] [G loss: [array(0.7142665, dtype=float32), array(0.7142665, dtype=float32), array(0.3181818, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 12 [D loss: 0.7152761220932007, acc.: 30.59895932674408%] [G loss: [array(0.7157923, dtype=float32), array(0.7157923, dtype=float32), array(0.2994792, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 13 [D loss: 0.7174255847930908, acc.: 28.44230830669403%] [G loss: [array(0.7180865, dtype=float32), array(0.7180865, dtype=float32), array(0.27884617, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 14 [D loss: 0.7192980051040649, acc.: 26.94072425365448%] [G loss: [array(0.7199265, dtype=float32), array(0.7199265, dtype=float32), array(0.26450893, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 15 [D loss: 0.720892071723938, acc.: 25.642961263656616%] [G loss: [array(0.7214674, dtype=float32), array(0.7214674, dtype=float32), array(0.25208336, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 16 [D loss: 0.7226818203926086, acc.: 24.41091239452362%] [G loss: [array(0.72343445, dtype=float32), array(0.72343445, dtype=float32), array(0.24023438, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 17 [D loss: 0.7242939472198486, acc.: 23.23278784751892%] [G loss: [array(0.7250646, dtype=float32), array(0.7250646, dtype=float32), array(0.22886029, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 18 [D loss: 0.7259693145751953, acc.: 22.363591194152832%] [G loss: [array(0.7268465, dtype=float32), array(0.7268465, dtype=float32), array(0.22048612, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 19 [D loss: 0.7277403473854065, acc.: 21.753866970539093%] [G loss: [array(0.7285531, dtype=float32), array(0.7285531, dtype=float32), array(0.21463816, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 20 [D loss: 0.7293462753295898, acc.: 20.889422297477722%] [G loss: [array(0.7301886, dtype=float32), array(0.7301886, dtype=float32), array(0.20625, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 21 [D loss: 0.7308700084686279, acc.: 20.63552439212799%] [G loss: [array(0.73172534, dtype=float32), array(0.73172534, dtype=float32), array(0.20386904, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 22 [D loss: 0.7329645156860352, acc.: 19.97390389442444%] [G loss: [array(0.7338663, dtype=float32), array(0.7338663, dtype=float32), array(0.19744319, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 23 [D loss: 0.7348451018333435, acc.: 19.37047243118286%] [G loss: [array(0.7357397, dtype=float32), array(0.7357397, dtype=float32), array(0.1915761, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 24 [D loss: 0.7366470694541931, acc.: 18.949466943740845%] [G loss: [array(0.7375981, dtype=float32), array(0.7375981, dtype=float32), array(0.1875, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 25 [D loss: 0.738362193107605, acc.: 18.309947848320007%] [G loss: [array(0.73925996, dtype=float32), array(0.73925996, dtype=float32), array(0.18124999, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 26 [D loss: 0.7398182153701782, acc.: 18.08422952890396%] [G loss: [array(0.7407089, dtype=float32), array(0.7407089, dtype=float32), array(0.17908655, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 27 [D loss: 0.7413614988327026, acc.: 17.933809757232666%] [G loss: [array(0.7423358, dtype=float32), array(0.7423358, dtype=float32), array(0.17766204, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 28 [D loss: 0.7430866956710815, acc.: 17.56899356842041%] [G loss: [array(0.7439848, dtype=float32), array(0.7439848, dtype=float32), array(0.17410715, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 29 [D loss: 0.744788408279419, acc.: 17.229562997817993%] [G loss: [array(0.74572575, dtype=float32), array(0.74572575, dtype=float32), array(0.17079741, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 30 [D loss: 0.7464152574539185, acc.: 16.91295951604843%] [G loss: [array(0.74733585, dtype=float32), array(0.74733585, dtype=float32), array(0.16770834, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 31 [D loss: 0.7480738162994385, acc.: 16.515319049358368%] [G loss: [array(0.74899775, dtype=float32), array(0.74899775, dtype=float32), array(0.16381048, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 32 [D loss: 0.7494928240776062, acc.: 16.438028216362%] [G loss: [array(0.75038844, dtype=float32), array(0.75038844, dtype=float32), array(0.16308594, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 33 [D loss: 0.7509065866470337, acc.: 16.27003252506256%] [G loss: [array(0.7518582, dtype=float32), array(0.7518582, dtype=float32), array(0.16145833, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 34 [D loss: 0.7524042725563049, acc.: 16.019397974014282%] [G loss: [array(0.753244, dtype=float32), array(0.753244, dtype=float32), array(0.15900736, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 35 [D loss: 0.7537617683410645, acc.: 15.91809093952179%] [G loss: [array(0.75465125, dtype=float32), array(0.75465125, dtype=float32), array(0.15803571, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 36 [D loss: 0.7551860809326172, acc.: 15.778744220733643%] [G loss: [array(0.7560264, dtype=float32), array(0.7560264, dtype=float32), array(0.15668403, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 37 [D loss: 0.7565503120422363, acc.: 15.51942527294159%] [G loss: [array(0.7573825, dtype=float32), array(0.7573825, dtype=float32), array(0.1541385, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 38 [D loss: 0.7578494548797607, acc.: 15.439417958259583%] [G loss: [array(0.75871044, dtype=float32), array(0.75871044, dtype=float32), array(0.1533717, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 39 [D loss: 0.7591204643249512, acc.: 15.282894670963287%] [G loss: [array(0.7599567, dtype=float32), array(0.7599567, dtype=float32), array(0.15184295, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 40 [D loss: 0.760563850402832, acc.: 15.016317367553711%] [G loss: [array(0.761394, dtype=float32), array(0.761394, dtype=float32), array(0.14921875, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 41 [D loss: 0.7618710994720459, acc.: 14.877860248088837%] [G loss: [array(0.76274157, dtype=float32), array(0.76274157, dtype=float32), array(0.14786585, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 42 [D loss: 0.7632555961608887, acc.: 14.746038615703583%] [G loss: [array(0.7640909, dtype=float32), array(0.7640909, dtype=float32), array(0.14657739, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 43 [D loss: 0.7646645307540894, acc.: 14.583832025527954%] [G loss: [array(0.7654882, dtype=float32), array(0.7654882, dtype=float32), array(0.14498547, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 44 [D loss: 0.7659163475036621, acc.: 14.571905136108398%] [G loss: [array(0.76671386, dtype=float32), array(0.76671386, dtype=float32), array(0.14488637, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 45 [D loss: 0.7670419812202454, acc.: 14.52559232711792%] [G loss: [array(0.76783043, dtype=float32), array(0.76783043, dtype=float32), array(0.14444445, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 46 [D loss: 0.7682369351387024, acc.: 14.34469074010849%] [G loss: [array(0.7690327, dtype=float32), array(0.7690327, dtype=float32), array(0.14266305, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 47 [D loss: 0.7694330811500549, acc.: 14.271798729896545%] [G loss: [array(0.77024823, dtype=float32), array(0.77024823, dtype=float32), array(0.14195478, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 48 [D loss: 0.7706981897354126, acc.: 14.071068167686462%] [G loss: [array(0.7714498, dtype=float32), array(0.7714498, dtype=float32), array(0.13997397, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 49 [D loss: 0.7717097997665405, acc.: 14.070883393287659%] [G loss: [array(0.7724435, dtype=float32), array(0.7724435, dtype=float32), array(0.13998725, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 50 [D loss: 0.7727030515670776, acc.: 14.007891714572906%] [G loss: [array(0.77343583, dtype=float32), array(0.77343583, dtype=float32), array(0.139375, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 51 [D loss: 0.7737213373184204, acc.: 13.978171348571777%] [G loss: [array(0.7744846, dtype=float32), array(0.7744846, dtype=float32), array(0.13909315, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 52 [D loss: 0.7747877836227417, acc.: 13.859018683433533%] [G loss: [array(0.7755018, dtype=float32), array(0.7755018, dtype=float32), array(0.13792068, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 53 [D loss: 0.7758821249008179, acc.: 13.744384050369263%] [G loss: [array(0.77662134, dtype=float32), array(0.77662134, dtype=float32), array(0.13679245, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 54 [D loss: 0.7769345641136169, acc.: 13.546805083751678%] [G loss: [array(0.77764064, dtype=float32), array(0.77764064, dtype=float32), array(0.13483797, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 55 [D loss: 0.7778836488723755, acc.: 13.442060351371765%] [G loss: [array(0.77858025, dtype=float32), array(0.77858025, dtype=float32), array(0.13380681, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 56 [D loss: 0.7788202166557312, acc.: 13.369104266166687%] [G loss: [array(0.7795216, dtype=float32), array(0.7795216, dtype=float32), array(0.13309152, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 57 [D loss: 0.7798298597335815, acc.: 13.216115534305573%] [G loss: [array(0.78052306, dtype=float32), array(0.78052306, dtype=float32), array(0.13157895, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 58 [D loss: 0.7807787656784058, acc.: 13.149596750736237%] [G loss: [array(0.7814537, dtype=float32), array(0.7814537, dtype=float32), array(0.13092673, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 59 [D loss: 0.7816307544708252, acc.: 13.165132701396942%] [G loss: [array(0.7822935, dtype=float32), array(0.7822935, dtype=float32), array(0.1310911, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 60 [D loss: 0.782516598701477, acc.: 13.101693987846375%] [G loss: [array(0.78319883, dtype=float32), array(0.78319883, dtype=float32), array(0.13046876, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 61 [D loss: 0.7833706140518188, acc.: 13.117505609989166%] [G loss: [array(0.7840254, dtype=float32), array(0.7840254, dtype=float32), array(0.13063525, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 62 [D loss: 0.7841986417770386, acc.: 13.082198798656464%] [G loss: [array(0.7848378, dtype=float32), array(0.7848378, dtype=float32), array(0.13029234, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 63 [D loss: 0.7849488854408264, acc.: 13.122719526290894%] [G loss: [array(0.7855756, dtype=float32), array(0.7855756, dtype=float32), array(0.13070437, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 64 [D loss: 0.7857822179794312, acc.: 13.063925504684448%] [G loss: [array(0.7864067, dtype=float32), array(0.7864067, dtype=float32), array(0.13012695, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 65 [D loss: 0.7866327166557312, acc.: 12.934556603431702%] [G loss: [array(0.78724486, dtype=float32), array(0.78724486, dtype=float32), array(0.12884615, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 66 [D loss: 0.7874417304992676, acc.: 12.785355746746063%] [G loss: [array(0.78803605, dtype=float32), array(0.78803605, dtype=float32), array(0.12736742, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 67 [D loss: 0.7881920337677002, acc.: 12.664034962654114%] [G loss: [array(0.7887855, dtype=float32), array(0.7887855, dtype=float32), array(0.12616605, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 68 [D loss: 0.7889391779899597, acc.: 12.638548016548157%] [G loss: [array(0.78952897, dtype=float32), array(0.78952897, dtype=float32), array(0.12591912, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 69 [D loss: 0.789728581905365, acc.: 12.56834864616394%] [G loss: [array(0.790307, dtype=float32), array(0.790307, dtype=float32), array(0.12522645, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 70 [D loss: 0.7904053926467896, acc.: 12.500159442424774%] [G loss: [array(0.79097545, dtype=float32), array(0.79097545, dtype=float32), array(0.12455357, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 71 [D loss: 0.7911060452461243, acc.: 12.411816418170929%] [G loss: [array(0.79166293, dtype=float32), array(0.79166293, dtype=float32), array(0.12367958, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 72 [D loss: 0.7917608022689819, acc.: 12.369488179683685%] [G loss: [array(0.7923024, dtype=float32), array(0.7923024, dtype=float32), array(0.12326389, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 73 [D loss: 0.7925336360931396, acc.: 12.263890355825424%] [G loss: [array(0.7930912, dtype=float32), array(0.7930912, dtype=float32), array(0.12221746, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 74 [D loss: 0.793149471282959, acc.: 12.224715948104858%] [G loss: [array(0.79369116, dtype=float32), array(0.79369116, dtype=float32), array(0.12183277, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 75 [D loss: 0.793745756149292, acc.: 12.270203977823257%] [G loss: [array(0.79427564, dtype=float32), array(0.79427564, dtype=float32), array(0.12229166, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 76 [D loss: 0.7944674491882324, acc.: 12.149472534656525%] [G loss: [array(0.7949828, dtype=float32), array(0.7949828, dtype=float32), array(0.12109375, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 77 [D loss: 0.7950283288955688, acc.: 12.194754183292389%] [G loss: [array(0.79554284, dtype=float32), array(0.79554284, dtype=float32), array(0.12155032, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 78 [D loss: 0.7956392765045166, acc.: 12.178581953048706%] [G loss: [array(0.7961504, dtype=float32), array(0.7961504, dtype=float32), array(0.12139423, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 79 [D loss: 0.796180248260498, acc.: 12.222345173358917%] [G loss: [array(0.796697, dtype=float32), array(0.796697, dtype=float32), array(0.12183545, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 80 [D loss: 0.7967360019683838, acc.: 12.186640501022339%] [G loss: [array(0.79724306, dtype=float32), array(0.79724306, dtype=float32), array(0.12148438, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 81 [D loss: 0.7973229289054871, acc.: 12.132468819618225%] [G loss: [array(0.7978155, dtype=float32), array(0.7978155, dtype=float32), array(0.12094907, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 82 [D loss: 0.7978789806365967, acc.: 12.175190448760986%] [G loss: [array(0.7983744, dtype=float32), array(0.7983744, dtype=float32), array(0.12137957, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 83 [D loss: 0.7983705997467041, acc.: 12.254643440246582%] [G loss: [array(0.79885286, dtype=float32), array(0.79885286, dtype=float32), array(0.12217621, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 84 [D loss: 0.7989225387573242, acc.: 12.220259010791779%] [G loss: [array(0.79940134, dtype=float32), array(0.79940134, dtype=float32), array(0.1218378, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 85 [D loss: 0.7994686365127563, acc.: 12.18668445944786%] [G loss: [array(0.79994005, dtype=float32), array(0.79994005, dtype=float32), array(0.12150735, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 86 [D loss: 0.7999598383903503, acc.: 12.15389370918274%] [G loss: [array(0.8004223, dtype=float32), array(0.8004223, dtype=float32), array(0.12118459, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 87 [D loss: 0.8004465103149414, acc.: 12.121858447790146%] [G loss: [array(0.80089545, dtype=float32), array(0.80089545, dtype=float32), array(0.12086925, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 88 [D loss: 0.8009918332099915, acc.: 12.072747945785522%] [G loss: [array(0.8014463, dtype=float32), array(0.8014463, dtype=float32), array(0.12038352, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 89 [D loss: 0.8015051484107971, acc.: 12.077561020851135%] [G loss: [array(0.8019534, dtype=float32), array(0.8019534, dtype=float32), array(0.12043539, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 90 [D loss: 0.8020147681236267, acc.: 12.030038237571716%] [G loss: [array(0.8024525, dtype=float32), array(0.8024525, dtype=float32), array(0.11996528, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 91 [D loss: 0.8024667501449585, acc.: 12.000779807567596%] [G loss: [array(0.8028987, dtype=float32), array(0.8028987, dtype=float32), array(0.1196772, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 92 [D loss: 0.8028980493545532, acc.: 11.989189684391022%] [G loss: [array(0.8033294, dtype=float32), array(0.8033294, dtype=float32), array(0.11956522, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 93 [D loss: 0.8033539056777954, acc.: 11.977849900722504%] [G loss: [array(0.8037807, dtype=float32), array(0.8037807, dtype=float32), array(0.11945564, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 94 [D loss: 0.8038187026977539, acc.: 11.966751515865326%] [G loss: [array(0.80423594, dtype=float32), array(0.80423594, dtype=float32), array(0.1193484, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 95 [D loss: 0.804307222366333, acc.: 11.93939745426178%] [G loss: [array(0.80471706, dtype=float32), array(0.80471706, dtype=float32), array(0.11907895, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 96 [D loss: 0.804728627204895, acc.: 11.912614107131958%] [G loss: [array(0.8051395, dtype=float32), array(0.8051395, dtype=float32), array(0.11881511, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 97 [D loss: 0.8050907254219055, acc.: 11.967135220766068%] [G loss: [array(0.80549824, dtype=float32), array(0.80549824, dtype=float32), array(0.11936212, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 98 [D loss: 0.8055230379104614, acc.: 11.924630403518677%] [G loss: [array(0.80592406, dtype=float32), array(0.80592406, dtype=float32), array(0.11894132, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 99 [D loss: 0.8059402704238892, acc.: 11.898810416460037%] [G loss: [array(0.8063381, dtype=float32), array(0.8063381, dtype=float32), array(0.11868687, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 100 [D loss: 0.8063986301422119, acc.: 11.810851097106934%] [G loss: [array(0.80678976, dtype=float32), array(0.80678976, dtype=float32), array(0.1178125, dtype=float32)]]
# Training abgeschlossen!
# 100 [D loss: 0.8063986301422119, acc.: 11.810851097106934%] [G loss: [array(0.80678976, dtype=float32), array(0.80678976, dtype=float32), array(0.1178125, dtype=float32)]]

# %%
# Verlustkurven plotten
plt.figure(figsize=(10, 5))
plt.plot(d_losses, label="Discriminator Loss")
plt.plot(g_losses, label="Generator Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.title("GAN Loss Curves")
plt.show()

# %% [markdown]
# ## Daten generieren

# %%
# Anzahl der zusätzlichen Teilnehmer, die generiert werden sollen
num_additional_participants = 250  # 250 Participants, jeder führt 4 Tests durch, ergibt 1000 Punkte
num_tests_per_participant = 4

# Höchste vorhandene Participant ID ermitteln
max_participant_id = data['participant_id'].max()

# Neue Participant IDs generieren
new_participant_ids = np.arange(max_participant_id + 1, max_participant_id + 1 + num_additional_participants)

# Test IDs für jeden neuen Teilnehmer festlegen (1, 2, 3, 4)
new_test_ids = np.tile(np.arange(1, num_tests_per_participant + 1), num_additional_participants)

# Erweiterung der Participant IDs, um die Test IDs zu matchen
extended_participant_ids = np.repeat(new_participant_ids, num_tests_per_participant)

# Zufälliges Rauschen generieren
noise = np.random.normal(0, 1, (num_additional_participants * num_tests_per_participant, latent_dim))

# IDs in Tensoren umwandeln und sicherstellen, dass die Form definiert ist
participant_ids_tensor = tf.constant(extended_participant_ids.reshape(-1, 1), dtype=tf.int32)
test_ids_tensor = tf.constant(new_test_ids.reshape(-1, 1), dtype=tf.int32)

# Fake-Daten generieren
synthetic_data_scaled = generator.predict([noise, participant_ids_tensor, test_ids_tensor])

# Die generierten Daten zurückskalieren auf den ursprünglichen Wertebereich
synthetic_data = scaler.inverse_transform(synthetic_data_scaled)

# IDs zu den generierten Daten hinzufügen
synthetic_data_with_ids = np.hstack((extended_participant_ids.reshape(-1, 1), new_test_ids.reshape(-1, 1), synthetic_data))

# Die generierten Daten mit den Originaldaten kombinieren
augmented_data = np.vstack((data.values, synthetic_data_with_ids))

# In ein TensorFlow-Dataset umwandeln
dataset = tf.data.Dataset.from_tensor_slices(augmented_data)

print("Original Data Shape:", data.shape)
print("Synthetic Data Shape:", synthetic_data_with_ids.shape)
print("Augmented Data Shape:", augmented_data.shape)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Original Data Shape: (188, 22)
# Synthetic Data Shape: (1000, 22)
# Augmented Data Shape: (1188, 22)

# %%
# Ausgewählte Datenpunkte plotten
synthetic_data_with_ids = pd.DataFrame(synthetic_data_with_ids, columns=data.columns)
print("Synthetic Data")
print(synthetic_data_with_ids[:25])

# Speichern der generierten Daten
synthetic_data_with_ids.to_csv('./../data/synthetic_data.csv', index=False)  

print("Synthetic Data saved successfully!")
# Out:
# Synthetic Data
#     participant_id  test_id  test_duration     mental   physical   temporal  \
# 0             48.0      1.0    2457.541016  99.942146  88.349716  85.022743
# 1             48.0      2.0    3216.318359  99.887375  86.043617  89.425423
# 2             48.0      3.0    2231.889160  99.812111  81.075165  93.060242
# 3             48.0      4.0    3019.165527  99.837517  85.310707  93.382240
# 4             49.0      1.0    1980.000244  99.518127  59.806534  89.902237
# 5             49.0      2.0    2831.922363  99.443497  75.080215  83.919006
# 6             49.0      3.0    2836.857910  99.280525  87.805786  76.747406
# 7             49.0      4.0    2970.849854  99.582191  64.887428  88.649117
# 8             50.0      1.0    1981.893188  99.914818  77.892090  87.668381
# 9             50.0      2.0    3480.327393  99.897018  89.057541  91.180428
# 10            50.0      3.0    3408.869385  98.395798  78.628181  80.109062
# 11            50.0      4.0    2211.189697  99.771866  83.894127  89.062416
# 12            51.0      1.0    2953.695801  99.861977  80.758919  88.859016
# 13            51.0      2.0    2932.253418  99.988953  92.239212  89.139542
# 14            51.0      3.0    2838.433350  99.743317  88.956337  80.000099
# 15            51.0      4.0    3582.984131  99.596733  69.097069  86.328934
# 16            52.0      1.0    2037.140503  99.051521  77.757195  90.323540
# 17            52.0      2.0    2828.349609  99.457634  82.137840  83.490685
# 18            52.0      3.0    2129.631836  99.708397  89.186646  78.212852
# 19            52.0      4.0    2961.327881  99.328606  69.440514  71.749657
# 20            53.0      1.0    2853.771240  99.167534  79.010384  84.237167
# 21            53.0      2.0    2608.079346  99.406616  77.789581  78.673317
# 22            53.0      3.0    1896.867188  99.808975  75.869667  86.792633
# 23            53.0      4.0    3978.077148  99.079475  79.701828  86.447861
# 24            54.0      1.0    2955.539551  99.723091  87.686989  96.809181
#
#     performance    effort  frustration       mean  ...  blinkrate  \
# 0     94.788925  5.218465    99.866005  84.015121  ...   0.002342
# 1     94.173859  5.517836    99.097282  83.230553  ...   0.000348
# 2     94.214859  5.829018    98.749657  82.434219  ...   0.003862
# 3     94.018661  5.162209    99.633156  83.838226  ...   0.005839
# 4     93.982292  5.951851    99.071693  82.312637  ...   0.016860
# 5     94.292007  7.760613    98.252800  82.603645  ...   0.008904
# 6     94.326134  7.326100    99.098228  82.942368  ...   0.011078
# 7     94.084816  6.156608    99.064842  82.614502  ...   0.004655
# 8     94.334564  5.603039    99.079315  83.722580  ...   0.002093
# 9     94.827316  5.143651    99.843323  83.946091  ...   0.001673
# 10    94.058739  6.433628    98.907959  82.494385  ...   0.010124
# 11    94.101982  5.737545    98.797287  83.502106  ...   0.001458
# 12    94.529427  5.154732    99.143120  83.994217  ...   0.001438
# 13    94.737274  5.170691    99.810768  84.004303  ...   0.000973
# 14    93.748909  6.617431    99.651573  82.923065  ...   0.008017
# 15    93.920647  5.395060    97.910072  83.981110  ...   0.002668
# 16    94.115616  7.405286    95.958015  81.726028  ...   0.006897
# 17    94.200706  7.009779    98.966553  83.296432  ...   0.021362
# 18    94.334145  5.999435    99.596664  82.868958  ...   0.005775
# 19    94.109352  6.245785    98.578491  83.062881  ...   0.017263
# 20    94.154678  6.278087    98.204300  83.287361  ...   0.003258
# 21    94.010948  6.186185    99.425682  82.743233  ...   0.008000
# 22    94.408783  6.062554    98.510124  81.973602  ...   0.004684
# 23    94.103683  6.737294    97.144608  83.351128  ...   0.003809
# 24    94.707962  5.571442    98.940117  83.356056  ...   0.001861
#
#     fixationrate  blinkrate_rel  blinkrate_rel_pct  fixationrate_rel  \
# 0       0.542765       0.908531        2568.840820         -0.262076
# 1       0.537629       0.907569        2247.370850         -0.261622
# 2       0.521290       0.903729        2159.256104         -0.255980
# 3       0.540963       0.906670        2288.240723         -0.261636
# 4       0.527292       0.902742        2141.524170         -0.256407
# 5       0.500405       0.902680        1615.520508         -0.247474
# 6       0.512733       0.908340        1707.777466         -0.259190
# 7       0.541247       0.898525        2834.111572         -0.255700
# 8       0.540616       0.906541        3056.260254         -0.261226
# 9       0.547004       0.908553        2738.962402         -0.263037
# 10      0.533530       0.906828        2367.776855         -0.253681
# 11      0.533783       0.906504        2598.549805         -0.253632
# 12      0.531593       0.908009        1788.292358         -0.261621
# 13      0.548257       0.908877        1805.823120         -0.262366
# 14      0.530568       0.907004        2835.497559         -0.256325
# 15      0.540053       0.903393        2506.080566         -0.258985
# 16      0.525006       0.904518        2161.130859         -0.239694
# 17      0.516776       0.904862        2146.855957         -0.256420
# 18      0.547202       0.908289        1984.449463         -0.253874
# 19      0.505139       0.904511        2193.169922         -0.252594
# 20      0.533976       0.903759        1715.677246         -0.253646
# 21      0.540122       0.905327        2198.323975         -0.256663
# 22      0.539223       0.898462        2313.019775         -0.252627
# 23      0.537591       0.901004        2882.605957         -0.251447
# 24      0.537751       0.907533        1896.295166         -0.261599
#
#     fixationrate_rel_pct  mean_pupil_diameter_rel  \
# 0             -95.444321                -1.449368
# 1             -96.304047                -1.449273
# 2             -93.241722                -1.378941
# 3             -94.825470                -1.456522
# 4             -90.081886                -1.347147
# 5             -94.874908                -1.239580
# 6             -83.758606                -1.299590
# 7             -92.171097                -1.323017
# 8             -97.686539                -1.352963
# 9             -95.999855                -1.469097
# 10            -87.587830                -1.262963
# 11            -95.751526                -1.389624
# 12            -97.984001                -1.435368
# 13            -98.048653                -1.465468
# 14            -96.749428                -1.433248
# 15            -93.244789                -1.317073
# 16            -88.685097                -1.162037
# 17            -96.223808                -1.418575
# 18            -97.360405                -1.406154
# 19            -95.830727                -1.351199
# 20            -88.247940                -1.324654
# 21            -90.961372                -1.213322
# 22            -84.890923                -1.318898
# 23            -90.027626                -1.343369
# 24            -97.442680                -1.463407
#
#     mean_pupil_diameter_rel_pct  median_pupil_diameter_rel  \
# 0                     20.703991                  -2.436105
# 1                     22.235310                  -2.432127
# 2                     22.906145                  -2.385204
# 3                     22.700460                  -2.437686
# 4                     19.550684                  -2.363615
# 5                     20.750038                  -2.195284
# 6                     23.930552                  -2.365591
# 7                     18.860806                  -2.379578
# 8                     24.109108                  -2.385482
# 9                     24.608620                  -2.447788
# 10                    21.521910                  -2.355749
# 11                    21.240192                  -2.359961
# 12                    22.880133                  -2.375155
# 13                    23.708366                  -2.448558
# 14                    20.154125                  -2.431879
# 15                    23.654917                  -2.377873
# 16                    20.892412                  -2.179933
# 17                    21.356112                  -2.367987
# 18                    21.298498                  -2.411867
# 19                    23.231209                  -2.305563
# 20                    22.612833                  -2.374177
# 21                    23.062643                  -2.374469
# 22                    21.676840                  -2.335668
# 23                    20.099823                  -2.310394
# 24                    22.731148                  -2.428826
#
#     median_pupil_diameter_rel_pct
# 0                       26.671213
# 1                       26.803642
# 2                       26.515074
# 3                       26.833233
# 4                       26.039680
# 5                       25.933279
# 6                       26.474672
# 7                       26.742331
# 8                       26.809872
# 9                       26.925709
# 10                      26.130457
# 11                      26.532169
# 12                      26.814207
# 13                      26.785444
# 14                      26.664606
# 15                      26.489075
# 16                      26.505751
# 17                      26.352509
# 18                      26.566153
# 19                      26.489811
# 20                      26.355949
# 21                      26.648094
# 22                      25.472752
# 23                      26.725794
# 24                      26.562790
#
# [25 rows x 22 columns]
# Synthetic Data saved successfully!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Konvertiere die augmented_data in ein DataFrame
augmented_df = pd.DataFrame(augmented_data, columns=data.columns)

# Getrennte DataFrames für Original- und generierte Daten
original_df = data.copy()
synthetic_df = augmented_df.iloc[len(data):].copy()

# Histogramme und Dichtekurven für jede Spalte
for column in data.columns:
    if column not in ['participant_id', 'test_id']:  # IDs auslassen
        plt.figure(figsize=(12, 6))
        sns.histplot(original_df[column], kde=True, color='blue', label='Original', stat='density')
        sns.histplot(synthetic_df[column], kde=True, color='red', label='Synthetic', stat='density')
        plt.title(f'Verteilung von {column}')
        plt.legend()
        plt.show()

# %%
from scipy.stats import ks_2samp

for column in data.columns:
    if column not in ['participant_id', 'test_id']:  # IDs auslassen
        stat, p_value = ks_2samp(original_df[column], synthetic_df[column])
        print(f'Kolmogorov-Smirnov-Test für {column}:')
        print(f'Statistik = {stat}, p-Wert = {p_value}')
        if p_value > 0.05:
            print("Die Verteilungen sind ähnlich (Nullhypothese nicht verworfen).")
        else:
            print("Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).")
        print()
# Out:
# Kolmogorov-Smirnov-Test für test_duration:
# Statistik = 0.9893617021276596, p-Wert = 5.839086879060571e-208
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).
#
# Kolmogorov-Smirnov-Test für mental:
# Statistik = 0.9627659574468085, p-Wert = 9.896672082807041e-182
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).
#
# Kolmogorov-Smirnov-Test für physical:
# Statistik = 0.8902553191489362, p-Wert = 1.1842997987221169e-139
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).
#
# Kolmogorov-Smirnov-Test für temporal:
# Statistik = 0.8036595744680851, p-Wert = 3.7636154577571015e-106
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).
#
# Kolmogorov-Smirnov-Test für performance:
# Statistik = 0.9787234042553191, p-Wert = 1.0550584695368058e-195
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).
#
# Kolmogorov-Smirnov-Test für effort:
# Statistik = 0.8985319148936171, p-Wert = 1.525671372148158e-143
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).
#
# Kolmogorov-Smirnov-Test für frustration:
# Statistik = 0.9840425531914894, p-Wert = 5.320311924057811e-202
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).
#
# Kolmogorov-Smirnov-Test für mean:
# Statistik = 0.9863617021276596, p-Wert = 2.723117895613837e-204
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).
#
# Kolmogorov-Smirnov-Test für mean_pupil_diameter:
# Statistik = 0.8746170212765958, p-Wert = 9.920313669275586e-133
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).
#
# Kolmogorov-Smirnov-Test für median_pupil_diameter:
# Statistik = 0.9893617021276596, p-Wert = 5.839086879060571e-208
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).
#
# Kolmogorov-Smirnov-Test für blinkrate:
# Statistik = 0.6721276595744681, p-Wert = 1.2065297538634696e-69
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).
#
# Kolmogorov-Smirnov-Test für fixationrate:
# Statistik = 0.9946808510638298, p-Wert = 6.104629496466038e-215
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).
#
# Kolmogorov-Smirnov-Test für blinkrate_rel:
# Statistik = 0.9946808510638298, p-Wert = 6.104629496466038e-215
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).
#
# Kolmogorov-Smirnov-Test für blinkrate_rel_pct:
# Statistik = nan, p-Wert = nan
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).
#
# Kolmogorov-Smirnov-Test für fixationrate_rel:
# Statistik = 0.9946808510638298, p-Wert = 6.104629496466038e-215
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).
#
# Kolmogorov-Smirnov-Test für fixationrate_rel_pct:
# Statistik = 0.9893617021276596, p-Wert = 5.839086879060571e-208
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).
#
# Kolmogorov-Smirnov-Test für mean_pupil_diameter_rel:
# Statistik = 0.9830425531914894, p-Wert = 6.786255016537361e-201
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).
#
# Kolmogorov-Smirnov-Test für mean_pupil_diameter_rel_pct:
# Statistik = 0.9241276595744681, p-Wert = 8.10266583901577e-157
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).
#
# Kolmogorov-Smirnov-Test für median_pupil_diameter_rel:
# Statistik = 0.9863617021276596, p-Wert = 2.723117895613837e-204
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).
#
# Kolmogorov-Smirnov-Test für median_pupil_diameter_rel_pct:
# Statistik = 0.9843617021276596, p-Wert = 5.32031192405776e-202
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).

# %%
import scipy.stats as stats
from scipy.stats import ttest_ind, kruskal

# Funktion zur Durchführung der Tests
def normality_test(data, column):
    stat, p_value = stats.shapiro(data[column])
    return p_value > 0.05  # Normal verteilt, wenn p-Wert > 0.05

def compare_means(original, synthetic, column):
    is_normal_original = normality_test(original, column)
    is_normal_synthetic = normality_test(synthetic, column)
    
    print(f'Normalitätstest für {column}:')
    print(f'Originaldaten: {"Normalverteilt" if is_normal_original else "Nicht-normalverteilt"}')
    print(f'Generierte Daten: {"Normalverteilt" if is_normal_synthetic else "Nicht-normalverteilt"}')
    
    if is_normal_original and is_normal_synthetic:
        # t-Test anwenden
        stat, p_value = ttest_ind(original[column], synthetic[column], equal_var=False)
        print(f't-Test für {column}:')
    else:
        # Kruskal-Wallis H-Test anwenden
        stat, p_value = kruskal(original[column], synthetic[column])
        print(f'Kruskal-Wallis H-Test für {column}:')
    
    print(f'Statistik = {stat}, p-Wert = {p_value}')
    if p_value > 0.05:
        print("Die Verteilungen sind ähnlich (Nullhypothese nicht verworfen).")
    else:
        print("Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).")
    print()



# Vergleiche die Verteilungen für jede Spalte
for column in data.columns:
    if column not in ['participant_id', 'test_id']:  # IDs auslassen
        compare_means(original_df, synthetic_df, column)
# Out:
# Normalitätstest für test_duration:
# Originaldaten: Nicht-normalverteilt
# Generierte Daten: Nicht-normalverteilt
# Kruskal-Wallis H-Test für test_duration:
# Statistik = 454.37790318096904, p-Wert = 8.042162371225988e-101
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).
#
# Normalitätstest für mental:
# Originaldaten: Nicht-normalverteilt
# Generierte Daten: Nicht-normalverteilt
# Kruskal-Wallis H-Test für mental:
# Statistik = 406.3383622873519, p-Wert = 2.297098309929205e-90
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).
#
# Normalitätstest für physical:
# Originaldaten: Nicht-normalverteilt
# Generierte Daten: Nicht-normalverteilt
# Kruskal-Wallis H-Test für physical:
# Statistik = 384.62163942640035, p-Wert = 1.2267992223757235e-85
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).
#
# Normalitätstest für temporal:
# Originaldaten: Nicht-normalverteilt
# Generierte Daten: Nicht-normalverteilt
# Kruskal-Wallis H-Test für temporal:
# Statistik = 330.61943733045246, p-Wert = 7.044877704912425e-74
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).
#
# Normalitätstest für performance:
# Originaldaten: Nicht-normalverteilt
# Generierte Daten: Nicht-normalverteilt
# Kruskal-Wallis H-Test für performance:
# Statistik = 454.1118489474294, p-Wert = 9.189088001693298e-101
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).
#
# Normalitätstest für effort:
# Originaldaten: Nicht-normalverteilt
# Generierte Daten: Nicht-normalverteilt
# Kruskal-Wallis H-Test für effort:
# Statistik = 340.9481249444022, p-Wert = 3.966310338698623e-76
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).
#
# Normalitätstest für frustration:
# Originaldaten: Nicht-normalverteilt
# Generierte Daten: Nicht-normalverteilt
# Kruskal-Wallis H-Test für frustration:
# Statistik = 464.05662832939413, p-Wert = 6.296615991425215e-103
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).
#
# Normalitätstest für mean:
# Originaldaten: Nicht-normalverteilt
# Generierte Daten: Nicht-normalverteilt
# Kruskal-Wallis H-Test für mean:
# Statistik = 458.32821876628026, p-Wert = 1.1109670007034828e-101
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).
#
# Normalitätstest für mean_pupil_diameter:
# Originaldaten: Nicht-normalverteilt
# Generierte Daten: Nicht-normalverteilt
# Kruskal-Wallis H-Test für mean_pupil_diameter:
# Statistik = 424.51134002418485, p-Wert = 2.543970581582967e-94
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).
#
# Normalitätstest für median_pupil_diameter:
# Originaldaten: Nicht-normalverteilt
# Generierte Daten: Nicht-normalverteilt
# Kruskal-Wallis H-Test für median_pupil_diameter:
# Statistik = 463.5408358281281, p-Wert = 8.153622241020733e-103
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).
#
# Normalitätstest für blinkrate:
# Originaldaten: Nicht-normalverteilt
# Generierte Daten: Nicht-normalverteilt
# Kruskal-Wallis H-Test für blinkrate:
# Statistik = 141.17892623208448, p-Wert = 1.470338312963817e-32
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).
#
# Normalitätstest für fixationrate:
# Originaldaten: Nicht-normalverteilt
# Generierte Daten: Nicht-normalverteilt
# Kruskal-Wallis H-Test für fixationrate:
# Statistik = 464.30937059766995, p-Wert = 5.547626214007219e-103
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).
#
# Normalitätstest für blinkrate_rel:
# Originaldaten: Nicht-normalverteilt
# Generierte Daten: Nicht-normalverteilt
# Kruskal-Wallis H-Test für blinkrate_rel:
# Statistik = 464.3633917483477, p-Wert = 5.399474474830648e-103
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).
#
# Normalitätstest für blinkrate_rel_pct:
# Originaldaten: Nicht-normalverteilt
# Generierte Daten: Nicht-normalverteilt
# Kruskal-Wallis H-Test für blinkrate_rel_pct:
# Statistik = nan, p-Wert = nan
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).
#
# Normalitätstest für fixationrate_rel:
# Originaldaten: Nicht-normalverteilt
# Generierte Daten: Nicht-normalverteilt
# Kruskal-Wallis H-Test für fixationrate_rel:
# Statistik = 464.33810531385404, p-Wert = 5.468322837217543e-103
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).
#
# Normalitätstest für fixationrate_rel_pct:
# Originaldaten: Nicht-normalverteilt
# Generierte Daten: Nicht-normalverteilt
# Kruskal-Wallis H-Test für fixationrate_rel_pct:
# Statistik = 464.27819265234893, p-Wert = 5.634973993481655e-103
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).
#
# Normalitätstest für mean_pupil_diameter_rel:
# Originaldaten: Nicht-normalverteilt
# Generierte Daten: Nicht-normalverteilt
# Kruskal-Wallis H-Test für mean_pupil_diameter_rel:
# Statistik = 463.000976711493, p-Wert = 1.0686401071304125e-102
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).
#
# Normalitätstest für mean_pupil_diameter_rel_pct:
# Originaldaten: Nicht-normalverteilt
# Generierte Daten: Nicht-normalverteilt
# Kruskal-Wallis H-Test für mean_pupil_diameter_rel_pct:
# Statistik = 438.27224520100634, p-Wert = 2.5732021876129554e-97
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).
#
# Normalitätstest für median_pupil_diameter_rel:
# Originaldaten: Nicht-normalverteilt
# Generierte Daten: Nicht-normalverteilt
# Kruskal-Wallis H-Test für median_pupil_diameter_rel:
# Statistik = 464.13841313553223, p-Wert = 6.043795483025287e-103
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).
#
# Normalitätstest für median_pupil_diameter_rel_pct:
# Originaldaten: Nicht-normalverteilt
# Generierte Daten: Nicht-normalverteilt
# Kruskal-Wallis H-Test für median_pupil_diameter_rel_pct:
# Statistik = 462.7118519114049, p-Wert = 1.2352338492215546e-102
# Die Verteilungen sind signifikant unterschiedlich (Nullhypothese verworfen).
